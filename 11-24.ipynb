# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
data = pd.read_csv('final_data.csv')
# Out:
# C:\Users\shnai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#                  comment_id  \
# 0       6816879848683438085
# 1       6816846992812015622
# 2       6816942564911628294
# 3       6816824764519301125
# 4       6816821633249001477
# ...                     ...
# 165105  6831297427954581509
# 165106  6831297361822711814
# 165107  6831297275164868613
# 165108  6842810518533652485
# 165109  6840892206023950342
#
#                                                      text  \
# 0       But are you giving him a Tesla? Because he des...
# 1                   David was just hoping for some help 😢
# 2       We ain’t forgot that time he tricked us all in...
# 3                                         get him a tesla
# 4                                        david ur so hung
# ...                                                   ...
# 165105                                      Sup I’m early
# 165106                                                 ￼￼
# 165107                                             Ayeeee
# ...

# %% [markdown]
# The main column I will analyze in terms of descriptive stats is the like counts column. I will analyze the mean, median as well as the quartiles. I will also be looking at correlations as well. I will also normlize the like counts after I have viewed the distribution. I could also normlalize the create_time.
#
# Questions:
# Is there a correlation between views and the amount of capital letters in the dataset?
#
# Does create time have a correlation like count?
#
# Do videos published by certain authors have a higher average view count?
#
# Does author privacy increase or decrease like count?
#
# Effect of region on view count

# %%
corr_matrix = data.corr()

# %%
plt.figure(figsize= (20,20))
sns.heatmap(corr_matrix, annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sc = StandardScaler()

# %%
def findCapital(text):
    cap_lets = []
    low_lets = []
    for i in text:
        if i.isupper():
            cap_lets.append(i)
        elif i.islower():
            low_lets.append(i)
    return len(cap_lets)

# %%
data['text'].apply(lambda x: findCapital(x))
# Out:
# 0         3
# 1         1
# 2         2
# 3         0
# 4         0
#          ..
# 165105    2
# 165106    0
# 165107    1
# 165108    0
# 165109    1
# Name: text, Length: 165110, dtype: int64

# %%
t = data[data['author.unique_id'] == 'nessza30']

# %%
t
# Out:
#                 comment_id                                               text  \
# 31269  6879080332458115077  Attempt #1 until david notices me and I win a ...
# 31445  6879080537219301382  Attempt #5 until david notices me and I win a ...
# 31447  6879080573814554630  Attempt #6 until david notices me and I win a ...
# 31449  6879080456076771334  Attempt #4 until david notices me and I win a ...
# 31450  6879080620069994501  Attempt #7 until david notices me and I win a ...
# ...                    ...                                                ...
# 62403  6879080416419004421  Attempt #3 until david notices me and I win a ...
# 62404  6879080387306356742  Attempt #2 until david notices me and I win a ...
# 62405  6879080620069994501  Attempt #7 until david notices me and I win a ...
# 62652  6879080332458115077  Attempt #1 until david notices me and I win a ...
# 62670  6879080456076771334  Attempt #4 until david notices me and I win a ...
#
# ...
